# %%
import numpy as np
import json
import geog
import shapely.geometry
from shapely.geometry import Point, shape
import pandas as pd
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt
from operator import itemgetter
import glob
import json
from ast import literal_eval
import osmnx as ox

# %%
stations_df = pd.read_csv("asemat.csv")
stations_df = gpd.GeoDataFrame(stations_df, geometry=gpd.points_from_xy(stations_df.X,stations_df.Y))

# %%
services_df = pd.read_csv("palvelut.csv")
services_df.location = services_df.location.apply(literal_eval)
services_df.location = services_df.location.apply(lambda x: Point(x['coordinates'][0], x['coordinates'][1]))
services_df = gpd.GeoDataFrame(services_df, geometry='location')
typesr = []
services_df['type'] = services_df['type'].apply(lambda x: literal_eval(x))
services_df['type'].apply(lambda x: typesr.append(x))
types = [t for t_ in typesr for t in t_]
types = set(types)
types
# Out:
# {'A1-englanti (perusopetuksen kieliohjelma)',
#  'A1-saksa (perusopetuksen kieliohjelma)',
#  'A2-englanti (perusopetuksen kieliohjelma)',
#  'B1-ruotsi (perusopetuksen kieliohjelma)',
#  'Kelan etuudet',
#  'aikuisten sosiaaliohjaus',
#  'aikuisten sosiaalityö',
#  'aikuisten terveyskeskuspäivystys ja päivystyspoliklinikka',
#  'ajoneuvojen siirrot',
#  'alueellinen kumppanuustyö',
#  'ammatillinen lisäkoulutus',
#  'ammatillinen peruskoulutus',
#  'ammatilliseen peruskoulutukseen valmentava koulutus - VALMA',
#  'apteekit',
#  'asemakaava-arkisto',
#  'asiakaspalvelu (energia)',
#  'asiakaspalvelu (joukkoliikenne)',
#  'asiakaspalvelu (kaavoitus)',
#  'asiakaspalvelu (työväenopisto)',
#  'asiakaspalvelu ja neuvonta (ammatillinen koulutus)',
#  'asiakaspalvelu ja neuvonta (lukiokoulutus)',
#  'asiakaspalvelu ja neuvonta (perusopetus)',
#  'asiakaspalvelu ja neuvonta (sosiaali- ja terveyspalvelut)',
#  'askartelu (nuorten harrastustila)',
#  'asukaspysäköintitunnukset',
#  'asumisen tuet',
#  'asuntotonttien vuokraus ja myynti',
#  'avioehtoasiat',
#  'avioeroasiat',
#  'avoin nuorisotoiminta (nuorten harrastustila)',
#  'avoin toiminta (lasten päivähoidon leikkitoiminta)',
#  'baarit ja yöelämä',
#  'beachvolleykentät',
#  'biljardi (nuorten harrastustila)',
#  'bänditoiminta tai -tila (nuorten harrastustila)',
#  'demostudio (nuorten harrastustila)',
#  'digitaalinen nuorisotyö',
#  'edunvalvonta (laki holhoustoimesta)',
#  'ehkäisevä toimeentulotuki',
#  'elokuvateatterit',
#  'eläintarhat',
#  'eläkeasiat',
#  'erikoiskirjastot',
#  'etuuskäsittely',
#  'frisbeegolf-radat',
#  'futsal (nuorten harrastustila)',
#  'fysioterapia',
#  'golfin harjoitusalueet',
#  'golfin harjoitushallit',
#  'golfkentät',
#  'hammashoito',
#  'hoitoalan ruokapalvelut',
#  'hotellit ja majoitus',
#  'hyvän olon palvelut',
#  'info- ja näyttelytilat (kaavoitus ja rakentaminen)',
#  'internet (nuorten harrastustila)',
#  'jalkapallo (nuorten harrastustila)',
#  'johtotietopalvelu ja maanalaisten tilojen tietopalvelu',
#  'joukkoliikennepysäkit',
#  'juhlatilat',
#  'julkinen notaari',
#  'julkishallinnon hallinnolliset toimipisteet',
#  'julkishallinnon henkilöstöravintolat',
#  'järjestötoiminta (nuorten harrastustila)',
#  'kaavat ja kaavoitus',
#  'kahvilat',
#  'kansainvälisten risteilyalusten laiturit',
#  'kansanopistot',
#  'kartonginkeräys',
#  'karttapalvelut, ilmakuvat ja karttojen tilaus',
#  'kasvitieteelliset puutarhat',
#  'katujen ja viheralueiden käyttöluvat ja vuokraus',
#  'katujen ja viheralueiden suunnittelu ja rakennuttaminen',
#  'katujen puhtaanapito ja talvikunnossapito',
#  'katutaidepaikat',
#  'kaupanvahvistus',
#  'kaupat ja myymälät',
#  'kauppa- ja yhdistysrekisteri',
#  'kauppahallimyyntipaikkojen vuokraus',
#  'kauppahallit',
#  'kaupungin tai kunnan vuokra-asunnot',
#  'kaupungin- ja kunnantalot',
#  'kaupungin- tai kunnanvaltuusto',
#  'kaupunginhallituksen ja -valtuuston valmistelutehtävät',
#  'kehitysvammahuollon sosiaaliohjaus',
#  'kehitysvammahuollon sosiaalityö',
#  'kehitysvammapoliklinikat',
#  'keilahallit',
#  'keramiikka (nuorten harrastustila)',
#  'kerhotoiminta (lasten päivähoidon leikkitoiminta)',
#  'kerhotoiminta (nuorten harrastustila)',
#  'kesätoiminta (nuorten harrastustila)',
#  'kierrätyskeskukset',
#  'kiipeilykalliot',
#  'kilpajäähallit',
#  'kioskit',
#  'kirjaamo',
#  'kirjastot (työväenopisto)',
#  'kirkot ja muut uskonnolliset tilat',
#  'kirpputorit',
#  'kokkikerho (nuorten harrastustila)',
#  'kokouspaikat',
#  'konserttitilat',
#  'konsolipelit (nuorten harrastustila)',
#  'kotikunta- ja väestötiedot',
#  'koulu- ja opiskelijaruokailu',
#  'koulukuraattorit',
#  'kouluterveydenhuolto',
#  'kulttuurihistorialliset museot',
#  'kulttuurin monitoimitalot',
#  'kulttuuripalvelujen sähköinen asiointi ja lomakkeet',
#  'kuluttajansuoja ja neuvonta',
#  'kuntosali (nuorten harrastustila)',
#  'kuntosalit',
#  'kuntouttava työtoiminta',
#  'kuntoutuksen apuvälinepalvelut',
#  'kuntoutuksen vuodeosastopalvelut',
#  'kuntoutuspsykiatria',
#  'kuntoutussuunnittelu ja -ohjaus',
#  'kurssitoiminnan opetustila',
#  'kuvataide (nuorten harrastustila)',
#  'kuvataidekoulut',
#  'kylpylät',
#  'kädentaidot (nuorten harrastustila)',
#  'käsityöt (nuorten harrastustila)',
#  'laboratoriot',
#  'laitoskirjastot',
#  'lapsiperheen tuet',
#  'lapsiperheiden lomatoiminta',
#  'lapsiperheiden sosiaaliohjaus',
#  'lasinkeräys',
#  'lasten terveyskeskuspäivystys ja päivystyspoliklinikka',
#  'lastenneuvolat',
#  'lastensuojelun sosiaalityö',
#  'lautapelit (nuorten harrastustila)',
#  'leikkikoulu (lasten päivähoidon leikkitoiminta)',
#  'leikkipaikat (ei ohjattua toimintaa)',
#  'leikkipuiston järjestämä iltapäivätoiminta',
#  'leirintäalueet',
#  'leiritoiminta (nuorten harrastustila)',
#  'liike- ja toimistotilojen vuokraus',
#  'liikennesuunnittelu',
#  'liikunta (nuorten harrastustila)',
#  'liikuntahallit',
#  'liikuntapuistot',
#  'liikuntasalit',
#  'lipunmyynti (eläintarha)',
#  'lipunmyynti (joukkoliikenne)',
#  'lipunmyynti (tapahtumat)',
#  'luistelukentät',
#  'luontokoulu (ympäristökasvatus)',
#  'luontopolut',
#  'luontotornit',
#  'lähiliikuntapaikat',
#  'lääkinnällinen kuntoutus',
#  'lääkärin vastaanotto',
#  'löytötavarapalvelu',
#  'maahanmuuttajapalvelut',
#  'maastomittauspalvelut',
#  'maauimalat',
#  'markkinat',
#  'matkailuneuvonta',
#  'matonpesupaikat',
#  'media (nuorten harrastustila)',
#  'metallinkeräys',
#  'metroasemat',
#  'mielenterveyskuntoutujien päivätoiminta',
#  'muovinkeräys',
#  'musiikki (nuorten harrastustila)',
#  'musiikkiopistot',
#  'muut matkailupalvelut',
#  'muut turvapalvelut (kiinteistöt ja vartiointi)',
#  'neuvolat',
#  'nimiasiat (nimilaki)',
#  'nuohous',
#  'nuorisotalot',
#  'nuorten neuvonta ja ohjaus',
#  'nuorten työpajatoiminta',
#  'nähtävyydet',
#  'näyttelytilat (kulttuuri)',
#  'ohjattu leikkipuistotoiminta (lasten päivähoidon leikkitoiminta)',
#  'omahoitotarvikejakelu',
#  'ongelmajäteasemat',
#  'ooppera- ja balettitilat',
#  'opastusta tietokoneen käytössä (digineuvonta)',
#  'opiskelija-asunnot',
#  'opiskeluterveydenhuolto',
#  'oppilaan ja opiskelijan tuet',
#  'ostospaikat',
#  'pahvinkeräys',
#  'pakastamotilojen vuokraus',
#  'pallokentät',
#  'paperinkeräys',
#  'parisuhteen rekisteröinti',
#  'parkour-alueet',
#  'parkoursalit',
#  'pelastusasemat',
#  'pelit (nuorten harrastustila)',
#  'perheneuvonta',
#  'perhesuunnittelu- ja ehkäisyneuvolat',
#  'perinnönjakoasiat',
#  'perustoimeentulotuki',
#  'pesäpallostadionit',
#  'petanque-hallit',
#  'pikaluisteluradat',
#  'pingis (nuorten harrastustila)',
#  'poikakerho / poikaryhmät (nuorten harrastustila)',
#  'poliisilaitokset ja -asemat',
#  'potilasasiamiehet',
#  'psykiatrian poliklinikat',
#  'psykiatrinen asumiskuntoutus',
#  'psykiatrinen perhehoito',
#  'psykiatriset päiväsairaalat',
#  'psykologitoiminta',
#  'psykoterapia',
#  'puheterapia',
#  'puolustusvoimat',
#  'puujätteen keräys',
#  'puutyö (nuorten harrastustila)',
#  'pysäköinninvalvonta',
#  'pysäköintilippuautomaatit',
#  'pyöräilyalueet',
#  'pyöräilyradat',
#  'pyöräkoulu (nuorten harrastustila)',
#  'päihdehuollon asumispalvelut',
#  'päihdehuollon katkaisuhoito ja kuntoutus',
#  'päihdehuollon korvaushoito',
#  'päihdehuollon polikliininen hoito',
#  'päihdehuollon päivätoiminta',
#  'päihdehuollon sosiaaliohjaus',
#  'päihdehuollon sosiaalityö',
#  'päivystyksen vuodeosastot',
#  'päiväsairaalat',
#  'pöytäfutis (nuorten harrastustila)',
#  'pöytäjääkiekko (nuorten harrastustila)',
#  'rakennus- ja toimenpideluvat',
#  'rakennusvalvontamittaukset',
#  'rautatieasemat',
#  'ravintolat',
#  'raviradat',
#  'retkeily (nuorten harrastustila)',
#  'rintamavetaraanien kuntoutus',
#  'ruoka - ja cateringpalvelut',
#  'ruotsinkielinen työväenopisto',
#  'röntgenit',
#  'sairaaloiden poliklinikat',
#  'salibandyhallit',
#  'siviilivihkiminen',
#  'skeittaus (nuorten harrastustila)',
#  'soitonopetus (nuorten harrastustila)',
#  'sopimuspalokunnat',
#  'sosiaali- ja terveydenhuollon kotihoito',
#  'sosiaalihuollon asumispalvelut',
#  'sosiaalihuollon työhön kuntoutus- ja työllistämispalvelut',
#  'sosiaalihuollon yhteiset tukipalvelut',
#  'sosiaalinen luotto',
#  'suomenkielinen ammatillinen koulutus',
#  'suomenkielinen ammattikorkeakoulukoulutus',
#  'suomenkielinen lisäopetus 10. luokka',
#  'suomenkielinen oppisopimuskoulutus',
#  'suomenkielinen perusopetus luokille 1-6',
#  'suomenkielinen työväenopisto',
#  'sähkö- ja elektroniikkaromun keräys',
#  'sähly (nuorten harrastustila)',
#  'taidemuseot',
#  'tanssi (nuorten harrastustila)',
#  'tanssitilat (esitykset)',
#  'tapahtumapaikat',
#  'tarjolla multimedialaitteita',
#  'tarjolla skanneri',
#  'tarjolla tulostin',
#  'tartuntataudit',
#  'teatterit',
#  'terveydenhoitajan vastaanotto',
#  'terveysasemat',
#  'terveyspalvelujen sähköinen asiointi ja lomakkeet',
#  'teurastamotilojen vuokraus',
#  'tietokoneopetus (kurssimuotoinen)',
#  'toimintaterapia',
#  'torimyyntipaikkojen vuokraus',
#  'torit',
#  'tuet ja avustukset',
#  'tuomioistuimet',
#  'tuotantotilojen vuokraus',
#  'tyttökerho / tyttöryhmät (nuorten harrastustila)',
#  'työterveyshuolto',
#  'työväenopiston opetustilat',
#  'täydentävä toimeentulotuki',
#  'uima-altaat',
#  'uimahallit',
#  'uimapaikat',
#  'uimarannat',
#  'ulkoilusaaret',
#  'ulkokuntoiluvälineet',
#  'valokuvaus (nuorten harrastustila)',
#  'valtuustotalot',
#  'vammaistukien ja -kuntoutuksen hakeminen',
#  'vanhuspalvelun palveluasuminen',
#  'vanhuspalvelun sosiaaliohjaus',
#  'vanhuspalvelun sosiaalityö',
#  'varastotilojen vuokraus',
#  'veistokset ja julkinen taide',
#  'veneiden talvisäilytys',
#  'venekerhojen venepaikat',
#  'venesatamat',
#  'vesikulkuneuvorekisteri',
#  'viestintä (rakentaminen)',
#  'viestintä ja vuorovaikutus (kaavoitus)',
#  'viheralueet',
#  'vihertukkutilojen vuokraus',
#  'viikonlopputoiminta (nuorten harrastustila)',
#  'voimailusalit',
#  'vuokrattavat harrastustilat',
#  'vuokrattavat nuorisotilat',
#  'vuokrattavat tilaussaunat',
#  'wlan-sisäpisteet',
#  'yhteispalvelupisteet ja yleisneuvonta',
#  'yksittäiset yleisurheilun suorituspaikat',
#  'yleiset kirjastot',
#  'yleiset pysäköintialueet',
#  'yleiset väestönsuojat',
#  'yliopistolliset sairaalat',
#  'yliopistot',
#  'ympäristöneuvonta',
#  'yrityspysäköintitunnukset',
#  'äitiysneuvolat',
#  'äänistudio (nuorten harrastustila)'}

# %%
# Take only the commercial services from the df
comtypes = ['apteekit', 'baarit ja yöelämä','elokuvateatterit',
            'hotellit ja majoitus','kahvilat','kaupat ja myymälät',
            'kioskit',  'lipunmyynti (tapahtumat)', 'ostospaikat', 'ravintolat','torit']

mask = services_df['type'].apply(lambda x: any(c for c in comtypes if c in x))
com_df = services_df[mask]
# Take all traffic nodes from the df
traftypes = [ 'joukkoliikennepysäkit', 'metroasemat', 'rautatieasemat', 'yleiset pysäköintialueet']
mask = services_df['type'].apply(lambda x: any(t for t in traftypes if t in x))
traf_df = services_df[mask]

# %%
# Cluster the commercial services
nclusters = 300
coords = com_df.location.apply(lambda x: [x.x, x.y])
coords = np.array(list(coords))
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters = nclusters, n_init=10)
kmeans.fit(coords)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=300, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
# Get all the clusters into a GeoDataFrame with coordinates and cluster size
clusters = {}
for label in kmeans.labels_:
    if str(label) not in clusters:
        clusters[str(label)] = {}
        clusters[str(label)]['label'] = int(label)
        clusters[str(label)]['x'] = float(kmeans.cluster_centers_[label][1])
        clusters[str(label)]['y'] = float(kmeans.cluster_centers_[label][0])
        clusters[str(label)]['n'] = 1
    else:
        clusters[str(label)]['n'] += 1

clusters_df= pd.DataFrame.from_dict(clusters, orient='index')
clusters_df

clusters_gdf = gpd.GeoDataFrame(clusters_df, geometry=gpd.points_from_xy(clusters_df.y,clusters_df.x))

# %%
clusters_gdf
# Out:
#      label          x          y   n                   geometry
# 20      20  60.166597  24.945503   9  POINT (24.94550 60.16660)
# 172    172  60.183368  24.924370   4  POINT (24.92437 60.18337)
# 82      82  60.229282  24.881021   1  POINT (24.88102 60.22928)
# 189    189  60.169978  24.927861   8  POINT (24.92786 60.16998)
# 281    281  60.166169  24.943684  14  POINT (24.94368 60.16617)
# ..     ...        ...        ...  ..                        ...
# 63      63  60.175026  24.980251   2  POINT (24.98025 60.17503)
# 230    230  60.179810  24.982718   1  POINT (24.98272 60.17981)
# 214    214  60.175419  24.984305   2  POINT (24.98431 60.17542)
# 122    122  60.174936  24.988665   2  POINT (24.98867 60.17494)
# 245    245  60.199220  24.940807   1  POINT (24.94081 60.19922)
#
# [300 rows x 5 columns]

# %%
def min_dist(point, gpd2):
    gpd2['Dist'] = gpd2.apply(lambda row:  point.distance(row.geometry),axis=1)
    geoseries = gpd2.iloc[gpd2['Dist'].argmin()]
    return geoseries

## Find the nearest commercial cluster of each bike station
stations_df['nearesr_comcluster'] = stations_df.apply(lambda row: min_dist(row.geometry,clusters_gdf)['label'] , axis=1)
stations_df
# Out:
#              X          Y  FID  \
# 0    24.950293  60.155445    1
# 1    24.956347  60.160959    2
# 2    24.944927  60.158189    3
# 3    24.941776  60.160986    4
# 4    24.936285  60.157948    5
# ..         ...        ...  ...
# 340  24.831397  60.235089  341
# 341  24.839390  60.220467  342
# 342  24.833536  60.220551  343
# 343  24.820635  60.223377  344
# 344  24.814794  60.204582  345
#
#                                                   data                name  \
# 0    {"name":"001 Kaivopuisto","coordinates":"60.15...         Kaivopuisto
# 1    {"name":"002 Laivasillankatu","coordinates":"6...     Laivasillankatu
# 2    {"name":"003 Kapteeninpuistikko","coordinates"...  Kapteeninpuistikko
# 3    {"name":"004 Viiskulma","coordinates":"60.1609...           Viiskulma
# 4    {"name":"005 Sepänkatu","coordinates":"60.1579...           Sepänkatu
# ..                                                 ...                 ...
# 340  {"name":"757 Painiitty","coordinates":"60.2350...           Painiitty
# 341  {"name":"761 Mäkkylän asema","coordinates":"60...      Mäkkylän asema
# 342  {"name":"763 Kalkkipellonmäki","coordinates":"...    Kalkkipellonmäki
# 343  {"name":"767 Ruutikatu","coordinates":"60.2233...           Ruutikatu
# 344  {"name":"769 Tiurintie","coordinates":"60.2045...           Tiurintie
#
#                                coordinate  total_slot operative   id  \
# 0    60.15544479382098,24.950292889690314          30       Yes    1
# 1    60.160959094315416,24.95634747175871          12       Yes    2
# 2                   60.1581892,24.9449274          16       Yes    3
# 3                   60.1609859,24.9417758          14       Yes    4
# 4                   60.1579483,24.9362853          32       Yes    5
# ..                                    ...         ...       ...  ...
# 340                  60.235089, 24.831397          12       Yes  757
# 341                  60.220467, 24.839390          32       Yes  761
# 342                   60.220551,24.833536          24       Yes  763
# 343                  60.223377, 24.820635          10       Yes  767
# 344                  60.204582, 24.814794          12       Yes  769
#
#                       geometry  nearesr_comcluster
# 0    POINT (24.95029 60.15544)                 150
# 1    POINT (24.95635 60.16096)                 179
# 2    POINT (24.94493 60.15819)                 204
# 3    POINT (24.94178 60.16099)                  47
# 4    POINT (24.93629 60.15795)                   0
# ..                         ...                 ...
# 340  POINT (24.83140 60.23509)                  37
# 341  POINT (24.83939 60.22047)                 170
# 342  POINT (24.83354 60.22055)                  37
# 343  POINT (24.82064 60.22338)                  37
# 344  POINT (24.81479 60.20458)                  88
#
# [345 rows x 11 columns]
